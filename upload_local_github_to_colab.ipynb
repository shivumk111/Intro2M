# %% [markdown]
# <a href="https://colab.research.google.com/github/shivumk111/Intro2M/blob/master/upload_local_github_to_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Access Local Drive**

# %% [markdown]
# copy and paste in file explorer to watch video on
#
# How to upload a local drive ipynb file and csv file.
#
#
# E:\dataAnalysis\colab\Upload_OpenFileFromLocalDrive.mp4

# %% [markdown]
# ##**Load and Access Files from GitHub Repository**

# %%
# !git clone https://github.com/shivumk111/msk.git  # run if no uploaded file

# %%
import pandas as pd

# %%
data = pd.read_csv('msk/sample_NaN_m.csv')
data.head()
# Out:
#    Sl Product Sales Person    Q1    Q2    Q3    Q4     SoldTo
# 0   1   Prod1         Rama  10.0  12.0  14.0  16.0  Hybrid Co
# 1   2   Prod2       Shyama   5.0   0.0   2.0   0.0     Region
# 2   3   Prod3        Bhama   5.0   6.0  14.0   6.0   Gajodhar
# 3   4   Prod4       Shyama   0.0  12.0   3.0   4.0     Region
# 4   5   Prod5        Pooja   2.0   5.0   7.0   8.0     Ahalya

# %%
import cv2

# %%
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread("msk/NaN.png")

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1077x705 at 0x7F59772A4990>
